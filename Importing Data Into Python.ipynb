# %%
import pandas as pd

# %%
#Method 1 specify full path

# %%
file=pd.read_csv('D:\\train.csv')

# %%
file
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# Method 2 for importing data is to change working directory.

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\kaushal.solanki\Desktop\Python Learning

# %%
#os.chdir('D:\\')

# %%
#Exploring Data

# %%
#give number of rows
len(file)
# Out:
# 891

# %%
#see columns
file.columns
# Out:
# Index([u'PassengerId', u'Survived', u'Pclass', u'Name', u'Sex', u'Age',
#        u'SibSp', u'Parch', u'Ticket', u'Fare', u'Cabin', u'Embarked'],
#       dtype='object')

# %%
#number of columns
len(file.columns)
# Out:
# 12

# %%
#top rows
file.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
file.tail(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 841          842         0       2
# 842          843         1       1
# 843          844         0       3
# 844          845         0       3
# 845          846         0       3
# 846          847         0       3
# 847          848         0       3
# 848          849         0       2
# 849          850         1       1
# 850          851         0       3
# 851          852         0       3
# 852          853         0       3
# 853          854         1       1
# 854          855         0       2
# 855          856         1       3
# 856          857         1       1
# 857          858         1       1
# 858          859         1       3
# 859          860         0       3
# 860          861         0       3
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# ...

# %%
#information on columns

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
#get statts on columns
file.describe()
# Out:
# C:\Users\kaushal.solanki\AppData\Local\Continuum\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# ...

# %%
file.describe().transpose()
# Out:
# C:\Users\kaushal.solanki\AppData\Local\Continuum\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# ...

# %%
#Renaming Columns of data

# %%
file.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
file.columns
# Out:
# Index([u'PassengerId', u'Survived', u'Pclass', u'Name', u'Sex', u'Age',
#        u'SibSp', u'Parch', u'Ticket', u'Fare', u'Cabin', u'Embarked'],
#       dtype='object')

# %%
file.columns=['A','b','c','d','e','f','g','h','i','j','k','l']

# %%
file.columns
# Out:
# Index([u'A', u'b', u'c', u'd', u'e', u'f', u'g', u'h', u'i', u'j', u'k', u'l'], dtype='object')

# %%
#subsetting data by rows, columns an combine them!!!

# %%
file[14:16]
# Out:
#      A  b  c                                     d       e     f  g  h  \
# 14  15  0  3  Vestrom, Miss. Hulda Amanda Adolfina  female  14.0  0  0
# 15  16  1  2      Hewlett, Mrs. (Mary D Kingcome)   female  55.0  0  0
#
#          i        j    k  l
# 14  350406   7.8542  NaN  S
# 15  248706  16.0000  NaN  S

# %%
#Reverse the dataframe
file[ : :-1]
# Out:
#        A  b  c                                                  d       e  \
# 890  891  0  3                                Dooley, Mr. Patrick    male
# 889  890  1  1                              Behr, Mr. Karl Howell    male
# 888  889  0  3           Johnston, Miss. Catherine Helen "Carrie"  female
# 887  888  1  1                       Graham, Miss. Margaret Edith  female
# 886  887  0  2                              Montvila, Rev. Juozas    male
# 885  886  0  3               Rice, Mrs. William (Margaret Norton)  female
# 884  885  0  3                             Sutehall, Mr. Henry Jr    male
# 883  884  0  2                      Banfield, Mr. Frederick James    male
# 882  883  0  3                       Dahlberg, Miss. Gerda Ulrika  female
# 881  882  0  3                                 Markun, Mr. Johann    male
# 880  881  1  2       Shelley, Mrs. William (Imanita Parrish Hall)  female
# 879  880  1  1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# ...

# %%
#Get every 20 th row
file[::20]
# Out:
#        A  b  c                                                  d       e  \
# 0      1  0  3                            Braund, Mr. Owen Harris    male
# 20    21  0  2                               Fynney, Mr. Joseph J    male
# 40    41  0  3     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female
# 60    61  0  3                              Sirayanian, Mr. Orsen    male
# 80    81  0  3                               Waelens, Mr. Achille    male
# 100  101  0  3                            Petranec, Miss. Matilda  female
# 120  121  0  2                        Hickman, Mr. Stanley George    male
# 140  141  0  3                      Boulos, Mrs. Joseph (Sultana)  female
# 160  161  0  3                           Cribb, Mr. John Hatfield    male
# 180  181  0  3                       Sage, Miss. Constance Gladys  female
# 200  201  0  3                     Vande Walle, Mr. Nestor Cyriel    male
# 220  221  1  3                     Sunderland, Mr. Victor Francis    male
# ...

# %%
#Working with columns
file.columns
# Out:
# Index([u'A', u'b', u'c', u'd', u'e', u'f', u'g', u'h', u'i', u'j', u'k', u'l'], dtype='object')

# %%
file.head()
# Out:
#    A  b  c                                                  d       e     f  \
# 0  1  0  3                            Braund, Mr. Owen Harris    male  22.0
# 1  2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2  3  1  3                             Heikkinen, Miss. Laina  female  26.0
# 3  4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4  5  0  3                           Allen, Mr. William Henry    male  35.0
#
#    g  h                 i        j     k  l
# 0  1  0         A/5 21171   7.2500   NaN  S
# 1  1  0          PC 17599  71.2833   C85  C
# 2  0  0  STON/O2. 3101282   7.9250   NaN  S
# 3  1  0            113803  53.1000  C123  S
# 4  0  0            373450   8.0500   NaN  S

# %%
file[['A','b']].head()
# Out:
#    A  b
# 0  1  0
# 1  2  1
# 2  3  1
# 3  4  1
# 4  5  0

# %%
file[['A','b']][4:8]
# Out:
#    A  b
# 4  5  0
# 5  6  0
# 6  7  0
# 7  8  0

# %%
file.head()
# Out:
#    A  b  c                                                  d       e     f  \
# 0  1  0  3                            Braund, Mr. Owen Harris    male  22.0
# 1  2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2  3  1  3                             Heikkinen, Miss. Laina  female  26.0
# 3  4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4  5  0  3                           Allen, Mr. William Henry    male  35.0
#
#    g  h                 i        j     k  l
# 0  1  0         A/5 21171   7.2500   NaN  S
# 1  1  0          PC 17599  71.2833   C85  C
# 2  0  0  STON/O2. 3101282   7.9250   NaN  S
# 3  1  0            113803  53.1000  C123  S
# 4  0  0            373450   8.0500   NaN  S

# %%
file[['A','b']]
# Out:
#        A  b
# 0      1  0
# 1      2  1
# 2      3  1
# 3      4  1
# 4      5  0
# 5      6  0
# 6      7  0
# 7      8  0
# 8      9  1
# 9     10  1
# 10    11  1
# 11    12  1
# 12    13  0
# 13    14  0
# 14    15  0
# 15    16  1
# 16    17  0
# 17    18  1
# 18    19  0
# 19    20  1
# 20    21  0
# 21    22  1
# 22    23  1
# 23    24  1
# 24    25  0
# 25    26  1
# 26    27  0
# 27    28  0
# 28    29  1
# 29    30  0
# ..   ... ..
# 861  862  0
# 862  863  1
# 863  864  0
# 864  865  0
# 865  866  1
# 866  867  1
# 867  868  0
# 868  869  0
# 869  870  1
# 870  871  0
# 871  872  1
# 872  873  0
# 873  874  0
# 874  875  1
# 875  876  1
# 876  877  0
# 877  878  0
# 878  879  0
# 879  880  1
# 880  881  1
# 881  882  0
# 882  883  0
# 883  884  0
# 884  885  0
# 885  886  0
# 886  887  0
# 887  888  1
# 888  889  0
# 889  890  1
# 890  891  0
#
# [891 rows x 2 columns]

# %%
#Mathematical Operaions

# %%
file.head()
# Out:
#    A  b  c                                                  d       e     f  \
# 0  1  0  3                            Braund, Mr. Owen Harris    male  22.0
# 1  2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2  3  1  3                             Heikkinen, Miss. Laina  female  26.0
# 3  4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4  5  0  3                           Allen, Mr. William Henry    male  35.0
#
#    g  h                 i        j     k  l
# 0  1  0         A/5 21171   7.2500   NaN  S
# 1  1  0          PC 17599  71.2833   C85  C
# 2  0  0  STON/O2. 3101282   7.9250   NaN  S
# 3  1  0            113803  53.1000  C123  S
# 4  0  0            373450   8.0500   NaN  S

# %%
file.drop('e',1)
# Out:
#        A  b  c                                                  d     f  g  h  \
# 0      1  0  3                            Braund, Mr. Owen Harris  22.0  1  0
# 1      2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  1  0
# 2      3  1  3                             Heikkinen, Miss. Laina  26.0  0  0
# 3      4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  1  0
# 4      5  0  3                           Allen, Mr. William Henry  35.0  0  0
# 5      6  0  3                                   Moran, Mr. James   NaN  0  0
# 6      7  0  1                            McCarthy, Mr. Timothy J  54.0  0  0
# 7      8  0  3                     Palsson, Master. Gosta Leonard   2.0  3  1
# 8      9  1  3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  0  2
# 9     10  1  2                Nasser, Mrs. Nicholas (Adele Achem)  14.0  1  0
# 10    11  1  3                    Sandstrom, Miss. Marguerite Rut   4.0  1  1
# ...

# %%
#Filtering Data Frames

# %%
file.head()
# Out:
#    A  b  c                                                  d       e     f  \
# 0  1  0  3                            Braund, Mr. Owen Harris    male  22.0
# 1  2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2  3  1  3                             Heikkinen, Miss. Laina  female  26.0
# 3  4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4  5  0  3                           Allen, Mr. William Henry    male  35.0
#
#    g  h                 i        j     k  l
# 0  1  0         A/5 21171   7.2500   NaN  S
# 1  1  0          PC 17599  71.2833   C85  C
# 2  0  0  STON/O2. 3101282   7.9250   NaN  S
# 3  1  0            113803  53.1000  C123  S
# 4  0  0            373450   8.0500   NaN  S

# %%
filter=file.A < 2

# %%
filter
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 861    False
# 862    False
# 863    False
# 864    False
# 865    False
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: A, dtype: bool

# %%
file[filter]
# Out:
#    A  b  c                        d     e     f  g  h          i     j    k  l
# 0  1  0  3  Braund, Mr. Owen Harris  male  22.0  1  0  A/5 21171  7.25  NaN  S

# %%
file[(file.A < 2) & (file.e=="male")]
# Out:
#    A  b  c                        d     e     f  g  h          i     j    k  l
# 0  1  0  3  Braund, Mr. Owen Harris  male  22.0  1  0  A/5 21171  7.25  NaN  S

# %%
file[file.e=="male"]
# Out:
#        A  b  c                                        d     e     f  g  h  \
# 0      1  0  3                  Braund, Mr. Owen Harris  male  22.0  1  0
# 4      5  0  3                 Allen, Mr. William Henry  male  35.0  0  0
# 5      6  0  3                         Moran, Mr. James  male   NaN  0  0
# 6      7  0  1                  McCarthy, Mr. Timothy J  male  54.0  0  0
# 7      8  0  3           Palsson, Master. Gosta Leonard  male   2.0  3  1
# 12    13  0  3           Saundercock, Mr. William Henry  male  20.0  0  0
# 13    14  0  3              Andersson, Mr. Anders Johan  male  39.0  1  5
# 16    17  0  3                     Rice, Master. Eugene  male   2.0  4  1
# 17    18  1  2             Williams, Mr. Charles Eugene  male   NaN  0  0
# 20    21  0  2                     Fynney, Mr. Joseph J  male  35.0  0  0
# 21    22  1  2                    Beesley, Mr. Lawrence  male  34.0  0  0
# 23    24  1  1             Sloper, Mr. William Thompson  male  28.0  0  0
# ...

# %%
file.head()
# Out:
#    A  b  c                                                  d       e     f  \
# 0  1  0  3                            Braund, Mr. Owen Harris    male  22.0
# 1  2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2  3  1  3                             Heikkinen, Miss. Laina  female  26.0
# 3  4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4  5  0  3                           Allen, Mr. William Henry    male  35.0
#
#    g  h                 i        j     k  l
# 0  1  0         A/5 21171   7.2500   NaN  S
# 1  1  0          PC 17599  71.2833   C85  C
# 2  0  0  STON/O2. 3101282   7.9250   NaN  S
# 3  1  0            113803  53.1000  C123  S
# 4  0  0            373450   8.0500   NaN  S

# %%
#How to get the unique variables
file.k.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6', 'C23 C25 C27',
#        'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33', 'F G73', 'E31',
#        'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101', 'F E69', 'D47',
#        'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4', 'A32', 'B4',
#        'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35', 'C87', 'B77',
#        'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19', 'B49', 'D',
#        'C22 C26', 'C106', 'C65', 'E36', 'C54', 'B57 B59 B63 B66', 'C7',
#        'E34', 'C32', 'B18', 'C124', 'C91', 'E40', 'T', 'C128', 'D37',
#        'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44', 'A34', 'C104', 'C111',
#        'C92', 'E38', 'D21', 'E12', 'E63', 'A14', 'B37', 'C30', 'D20',
#        'B79', 'E25', 'D46', 'B73', 'C95', 'B38', 'B39', 'B22', 'C86',
#        'C70', 'A16', 'C101', 'C68', 'A10', 'E68', 'B41', 'A20', 'D19',
#        'D50', 'D9', 'A23', 'B50', 'A26', 'D48', 'E58', 'C126', 'B71',
# ...

# %%
file.columns
# Out:
# Index([u'A', u'b', u'c', u'd', u'e', u'f', u'g', u'h', u'i', u'j', u'k', u'l'], dtype='object')

# %%
file[file.l== "S"]
# Out:
#        A  b  c                                                  d       e  \
# 0      1  0  3                            Braund, Mr. Owen Harris    male
# 2      3  1  3                             Heikkinen, Miss. Laina  female
# 3      4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4      5  0  3                           Allen, Mr. William Henry    male
# 6      7  0  1                            McCarthy, Mr. Timothy J    male
# 7      8  0  3                     Palsson, Master. Gosta Leonard    male
# 8      9  1  3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 10    11  1  3                    Sandstrom, Miss. Marguerite Rut  female
# 11    12  1  1                           Bonnell, Miss. Elizabeth  female
# 12    13  0  3                     Saundercock, Mr. William Henry    male
# 13    14  0  3                        Andersson, Mr. Anders Johan    male
# 14    15  0  3               Vestrom, Miss. Hulda Amanda Adolfina  female
# ...

# %%
file[file.e== "male"]
# Out:
#        A  b  c                                        d     e     f  g  h  \
# 0      1  0  3                  Braund, Mr. Owen Harris  male  22.0  1  0
# 4      5  0  3                 Allen, Mr. William Henry  male  35.0  0  0
# 5      6  0  3                         Moran, Mr. James  male   NaN  0  0
# 6      7  0  1                  McCarthy, Mr. Timothy J  male  54.0  0  0
# 7      8  0  3           Palsson, Master. Gosta Leonard  male   2.0  3  1
# 12    13  0  3           Saundercock, Mr. William Henry  male  20.0  0  0
# 13    14  0  3              Andersson, Mr. Anders Johan  male  39.0  1  5
# 16    17  0  3                     Rice, Master. Eugene  male   2.0  4  1
# 17    18  1  2             Williams, Mr. Charles Eugene  male   NaN  0  0
# 20    21  0  2                     Fynney, Mr. Joseph J  male  35.0  0  0
# 21    22  1  2                    Beesley, Mr. Lawrence  male  34.0  0  0
# 23    24  1  1             Sloper, Mr. William Thompson  male  28.0  0  0
# ...

# %%
file.head()
# Out:
#    A  b  c                                                  d       e     f  \
# 0  1  0  3                            Braund, Mr. Owen Harris    male  22.0
# 1  2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2  3  1  3                             Heikkinen, Miss. Laina  female  26.0
# 3  4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4  5  0  3                           Allen, Mr. William Henry    male  35.0
#
#    g  h                 i        j     k  l
# 0  1  0         A/5 21171   7.2500   NaN  S
# 1  1  0          PC 17599  71.2833   C85  C
# 2  0  0  STON/O2. 3101282   7.9250   NaN  S
# 3  1  0            113803  53.1000  C123  S
# 4  0  0            373450   8.0500   NaN  S

# %%
file.iat[2,4]
# Out:
# 'female'

# %%
file.at[2,'d']
# Out:
# 'Heikkinen, Miss. Laina'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
vis1=sns.timeseries[file['e']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-a41c7d0614a3> in <module>()
# ----> 1 vis1=sns.timeseries[file['e']]
#
# C:\Users\kaushal.solanki\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# C:\Users\kaushal.solanki\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
sns.set(style="darkgrid")

# Load the long-form example gammas dataset
gammas = sns.load_dataset("file")

# Plot the response with standard error
sns.tsplot(data=gammas, time="timepoint", unit="subject",
           condition="e", value="BOLD signal")
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-23-52a7968ebf51> in <module>()
#       2
#       3 # Load the long-form example gammas dataset
# ----> 4 gammas = sns.load_dataset("file")
#       5
#       6 # Plot the response with standard error
#
# C:\Users\kaushal.solanki\AppData\Local\Continuum\Anaconda2\lib\site-packages\seaborn\utils.pyc in load_dataset(name, cache, data_home, **kws)
#     425         full_path = cache_path
#     426
# --> 427     df = pd.read_csv(full_path, **kws)
#     428     if df.iloc[-1].isnull().all():
#     429         df = df.iloc[:-1]
#
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
vis3=sns.lmplot(x='Pclass',y='Fare',data=file,fit_reg=False)

# %%
vis2=sns.distplot(file['Fare'])

# %%
vis2=sns.boxplot(data=file,x='Pclass',y='Fare')

# %%
#scatter_kws={"s":100} used for size of marker
vis3=sns.lmplot(x='Pclass',y='Fare',data=file,fit_reg=False,scatter_kws={"s":100})
